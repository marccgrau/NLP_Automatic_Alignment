# %%
import os

# %%
if not os.path.exists("scripts/tokenizers/process_asr_text_tokenizer.py"):
  # !mkdir scripts
  # !wget -P scripts/ https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tokenizers/process_asr_text_tokenizer.py
# Out:
# mkdir: cannot create directory ‘scripts’: File exists
# --2022-06-20 12:29:41--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tokenizers/process_asr_text_tokenizer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13359 (13K) [text/plain]
# Saving to: ‘scripts/process_asr_text_tokenizer.py.2’
#
# process_asr_text_to 100%[===================>]  13.05K  --.-KB/s    in 0s
#
# 2022-06-20 12:29:41 (43.0 MB/s) - ‘scripts/process_asr_text_tokenizer.py.2’ saved [13359/13359]

# %%
data_dir = "data/voice/SZ_parliament"

# %%
# !python ./scripts/process_asr_text_tokenizer.py \
  --manifest="{data_dir}/train_manifest.json" \
  --data_root="{data_dir}/tokenizers/" \
  --vocab_size=1024 \
  --tokenizer="spe" \
  --no_lower_case \
  --spe_type="bpe" \
  --log
# Out:
# INFO:root:Corpus already exists at path : data/voice/SZ_parliament/tokenizers/text_corpus/document.txt
# [NeMo I 2022-06-20 12:29:54 sentencepiece_tokenizer:307] Processing data/voice/SZ_parliament/tokenizers/text_corpus/document.txt and store at data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=data/voice/SZ_parliament/tokenizers/text_corpus/document.txt --model_prefix=data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024/tokenizer --vocab_size=1024 --shuffle_input_sentence=true --hard_vocab_limit=false --model_type=bpe --character_coverage=1.0 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/voice/SZ_parliament/tokenizers/text_corpus/document.txt
#   input_format:
#   model_prefix: data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024/tokenizer
#   model_type: BPE
#   vocab_size: 1024
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: data/voice/SZ_parliament/tokenizers/text_corpus/document.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 2288 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=297925
# trainer_interface.cc(487) LOG(INFO) Alphabet size=71
# trainer_interface.cc(488) LOG(INFO) Final character coverage=1
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 2288 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 2288
# trainer_interface.cc(537) LOG(INFO) Done! 9191
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=9669 min_freq=1
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1567 size=20 all=1812 active=1741 piece=und
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=967 size=40 all=2275 active=2204 piece=it
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=747 size=60 all=3050 active=2979 piece=▁G
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=549 size=80 all=3695 active=3624 piece=ten
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=440 size=100 all=4197 active=4126 piece=anz
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=434 min_freq=29
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=332 size=120 all=4689 active=1463 piece=▁auf
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=286 size=140 all=5129 active=1903 piece=▁haben
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=246 size=160 all=5545 active=2319 piece=▁sich
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=216 size=180 all=5853 active=2627 piece=ul
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=191 size=200 all=6286 active=3060 piece=ran
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=191 min_freq=26
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=172 size=220 all=6709 active=1405 piece=▁kön
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=155 size=240 all=7009 active=1705 piece=▁Es
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=136 size=260 all=7271 active=1967 piece=acht
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=124 size=280 all=7534 active=2230 piece=gel
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=115 size=300 all=7876 active=2572 piece=▁Ber
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=115 min_freq=23
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=106 size=320 all=8171 active=1284 piece=ünf
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=98 size=340 all=8412 active=1525 piece=▁zur
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=92 size=360 all=8650 active=1763 piece=▁sein
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=87 size=380 all=8956 active=2069 piece=ation
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=79 size=400 all=9182 active=2295 piece=ige
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=79 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=73 size=420 all=9401 active=1188 piece=tel
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=69 size=440 all=9596 active=1383 piece=geb
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=460 all=9809 active=1596 piece=▁eigen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=480 all=10030 active=1817 piece=ru
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=500 all=10296 active=2083 piece=cht
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=58 min_freq=18
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=55 size=520 all=10471 active=1158 piece=art
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=53 size=540 all=10669 active=1356 piece=▁komm
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=50 size=560 all=10821 active=1508 piece=▁entsp
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=47 size=580 all=10955 active=1642 piece=ord
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=46 size=600 all=11126 active=1813 piece=▁unsere
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=46 min_freq=16
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=44 size=620 all=11291 active=1166 piece=gesetz
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=42 size=640 all=11461 active=1336 piece=bl
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=41 size=660 all=11656 active=1531 piece=▁also
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=40 size=680 all=11722 active=1597 piece=▁Unternehmen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=38 size=700 all=11830 active=1705 piece=▁beim
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=38 min_freq=14
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=36 size=720 all=12018 active=1189 piece=satz
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=35 size=740 all=12207 active=1378 piece=ohn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=34 size=760 all=12391 active=1562 piece=issen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=33 size=780 all=12567 active=1738 piece=▁meine
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=32 size=800 all=12673 active=1844 piece=räsident
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=32 min_freq=13
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=31 size=820 all=12775 active=1098 piece=ehrpersonen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=29 size=840 all=12874 active=1197 piece=.--
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=29 size=860 all=12964 active=1287 piece=igung
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=28 size=880 all=13057 active=1380 piece=von
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=27 size=900 all=13137 active=1460 piece=pl
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=27 min_freq=12
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=27 size=920 all=13331 active=1174 piece=▁sechs
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=26 size=940 all=13399 active=1242 piece=▁erwäh
# trainer_interface.cc(615) LOG(INFO) Saving model: data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024/tokenizer.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024/tokenizer.vocab
# Serialized tokenizer at location : data/voice/SZ_parliament/tokenizers/tokenizer_spe_bpe_v1024
# INFO:root:Done!
